# %%
# 라이브러리 import
from selenium import webdriver
import time
import pandas as pd
import re
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

from webdriver_manager.chrome import ChromeDriverManager

# %%
# 크롬드라이버 제어
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument('--disable-dex-shm-usage')


keys = Keys()

# %%
url_list = ['https://smartstore.naver.com/eaudelune/products/3307356053?NaPm=ct%3Dlb0cjzts%7Cci%3D3c4677c408144f6b78b0a0ac63fba6ed01cab33c%7Ctr%3Dslsl%7Csn%3D746681%7Chk%3D6d2e95010a2d454d0871c612c4002611fe6e6614']
driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1752\3003542941.py:2: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)

# %%
all_count=0
text_list= []
star_list= []
date_list= []

for target_url in url_list:
    end = False
    
    driver.get(target_url)
    driver.implicitly_wait(3)
    time.sleep(1)
    count = 0
    
    review_num = driver.find_element('xpath', '//*[@id="content"]/div/div[2]/div[1]/div[2]/div[1]/a/strong')
    review_num = review_num.text
    review_num = re.sub('[^#0-9 ]',"", review_num)
    review_num = int(review_num)
    
    driver.find_element('xpath', '//*[@id="content"]/div/div[3]/div[3]/ul/li[2]/a').click()
    
    time.sleep(1)
    
    while(True):
        for i in range(20):
            # 공통 경로
            path = driver.find_element('xpath', f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul/li[{i+1}]/div')
            try: # 판매자 댓글 없을때                    
                review = path.find_element('xpath', 'div/div/div[1]/div/div[1]/div[2]/div')
                star = path.find_element('xpath', 'div/div/div[1]/div/div[1]/div[1]/div[2]/div[1]/em')
                date = path.find_element('xpath', 'div/div/div[1]/div/div[1]/div[1]/div[2]/div[2]/span')

            except:
                try: # 판매자 댓글 있을때
                    review = path.find_element('xpath', 'div[1]/div/div[1]/div/div[1]/div[2]/div')
                    star = path.find_element('xpath', 'div[1]/div/div[1]/div/div[1]/div[1]/div[2]/div[1]/em')
                    date = path.find_element('xpath', 'div[1]/div/div[1]/div/div/div[1]/div[2]/div[2]/span')

                except: # 경로가 다른경우
                    review = path.find_element('xpath', 'div/div/div[1]/div/div/div[2]/div')
                    star = path.find_element('xpath', 'div/div/div[1]/div/div/div[1]/div[2]/div[1]/em')
                    date = path.find_element('xpath', 'div/div/div[1]/div/div/div[1]/div[2]/div[2]/span')
                    
            r_span_num = len(review.find_elements('xpath','span'))
            
            if r_span_num == 1: # BEST, 한달사용기 등이 없을때
                review = review.find_element('xpath', 'span')
            else: # 있을때
                review = review.find_element('xpath', f'span[{r_span_num}]')
                
            review = review.text
            review = re.sub('[^#0-9a-zA-Zㄱ-ㅣ가-힣 ]',"", review)
            star = star.text
            star = re.sub('[^#0-9 ]',"", star)
            date = date.text
            text_list.append(review)
            star_list.append(star)
            date_list.append(date)
            
            count = count + 1
            all_count = all_count + 1
            
            if count == review_num:
                end = True
                print('{}개 리뷰 크롤링, 다음'.format(count))
                break
        
        print('총 {}개 리뷰 크롤링'.format(all_count))
        
        if end:
            break
        
        next = 12
        next_bool = True
        while(next_bool): # 다음 버튼 클릭
            try:
                driver.find_element('xpath', f'//*[@id="REVIEW"]/div/div[3]/div[2]/div/div/a[{next}]').click()
                next_bool = False
            except:
                next = next -1
                
        driver.implicitly_wait(3)
        time.sleep(2)
# Out:
# 총 20개 리뷰 크롤링
# 총 40개 리뷰 크롤링
# 총 60개 리뷰 크롤링
# 총 80개 리뷰 크롤링
# 총 100개 리뷰 크롤링
# 총 120개 리뷰 크롤링
# 총 140개 리뷰 크롤링
# 총 160개 리뷰 크롤링
# 총 180개 리뷰 크롤링
# 총 200개 리뷰 크롤링
# 총 220개 리뷰 크롤링
# 총 240개 리뷰 크롤링
# 총 260개 리뷰 크롤링
# 총 280개 리뷰 크롤링
# 총 300개 리뷰 크롤링
# 총 320개 리뷰 크롤링
# 총 340개 리뷰 크롤링
# 총 360개 리뷰 크롤링
# 총 380개 리뷰 크롤링
# 총 400개 리뷰 크롤링
# 총 420개 리뷰 크롤링
# 총 440개 리뷰 크롤링
# 총 460개 리뷰 크롤링
# 총 480개 리뷰 크롤링
# 총 500개 리뷰 크롤링
# 총 520개 리뷰 크롤링
# 총 540개 리뷰 크롤링
# 총 560개 리뷰 크롤링
# 총 580개 리뷰 크롤링
# 총 600개 리뷰 크롤링
# 총 620개 리뷰 크롤링
# 총 640개 리뷰 크롤링
# 총 660개 리뷰 크롤링
# 총 680개 리뷰 크롤링
# 총 700개 리뷰 크롤링
# 총 720개 리뷰 크롤링
# 총 740개 리뷰 크롤링
# 총 760개 리뷰 크롤링
# 772개 리뷰 크롤링, 다음
# 총 772개 리뷰 크롤링

# %%
len(text_list), len(star_list)
# Out:
# (772, 772)

# %%
data = {'date' : date_list,
        'star' : star_list,
        'text' : text_list
        }

df = pd.DataFrame(data)

df['date'] = pd.to_datetime(('20' + df['date']))

len(df)
# Out:
# 772

# %%
df.dropna(inplace=True) # 글이없는 리뷰 드랍
df.reset_index(drop=True, inplace=True)

# %%
df[df.text.str.contains('BEST|한달사용기|재구매')] # 머릿말 들어갔는지 확인
# Out:
#           date star                                               text
# 20  2022-10-30    5  포장이 잘되어있고 너무 꼼꼼해서 포장을 땔수가 없을 줄알았눈데 전혀 맛은 달달해서 ...
# 35  2022-09-28    5  엄마 고향 와인이라 우선 너무 방가웠어요부모님을 위한 와인을 찾다가 적당히 달고 포...
# 38  2022-10-19    5  진짜 포장 세상최고 꼼꼼해서 뜯으면서 감탄했어요ㅋㅋ 주말에 마실꺼라 아직 맛은 모르...
# 57  2022-08-31    5  협찬완잔 꼼꼼배송으로도착유리병이라 걱정했는데 그런 걱정 1도 없게 포장해주셨어요 일...
